# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# Out:
# ERROR: No traceback has been produced, nothing to debug.

# %%
np.random.seed(12)
plt.figure(figsize=(10,6))
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    plt.plot(x,y,label=str(i))

plt.legend()

# %%
import prettyplotlib as ppl
np.random.seed(12)
# ppl.figure(figsize=(10,6))
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    ppl.plot(x, y, label=str(i))
ppl.legend()
# Out:
# /Users/Jackie/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
np.random.seed(12)
plt.pcolormesh(np.random.rand(16, 16))
plt.colorbar()

# %%
np.random.seed(12)
ppl.pcolormesh(np.random.rand(16, 16))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
np.random.seed(12)
x1 = np.random.randn(80)
x2 = np.random.randn(80)
x3 = x1 * x2


y1 = .5 + 2 * x1 - x2 + 2.5 * x3 + 3 * np.random.randn(80)
y2 = .5 + 2 * x1 - x2 + 2.5 * np.random.randn(80)
y3 = y2 + np.random.randn(80)

# %%
sns.violinplot(x1)
sns.violinplot(x2)
sns.violinplot(x3)

# %%
sns.regplot(x2, y2)

# %%
import pandas as pd

df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3,y1=y1, y2=y2, y3=y3))
df.sns.corrplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-85670694f648> in <module>()
#       2
#       3 df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3,y1=y1, y2=y2, y3=y3))
# ----> 4 df.sns.corrplot()
#       5 get_ipython().magic(u'debug')
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sns'

# %%
# %debug
# Out:
# > /Users/Jackie/anaconda/lib/python2.7/site-packages/pandas/core/generic.py(2744)__getattr__()
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# ipdb> p
# *** SyntaxError: SyntaxError('unexpected EOF while parsing', ('<string>', 0, 0, ''))
# ipdb> w
#   <ipython-input-13-85670694f648>(4)<module>()
#       1 import pandas as pd
#       2
#       3 df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3,y1=y1, y2=y2, y3=y3))
# ----> 4 df.sns.corrplot()
#       5 get_ipython().magic(u'debug')
#
# > /Users/Jackie/anaconda/lib/python2.7/site-packages/pandas/core/generic.py(2744)__getattr__()
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# ipdb> w
#   <ipython-input-13-85670694f648>(4)<module>()
#       1 import pandas as pd
#       2
#       3 df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3,y1=y1, y2=y2, y3=y3))
# ----> 4 df.sns.corrplot()
#       5 get_ipython().magic(u'debug')
#
# > /Users/Jackie/anaconda/lib/python2.7/site-packages/pandas/core/generic.py(2744)__getattr__()
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# ipdb> l
#    2739                 name in self._accessors):
#    2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#    2747         """After regular attribute access, try setting the name
#    2748         This allows simpler access to columns for interactive use.
#    2749         """
#
# ipdb> a
# self =           x1        x2        x3         y1         y2         y3
# 0   0.472986 -1.339389 -0.633512   2.145101   3.346728   2.835365
# 1  -0.681426 -1.689653  1.151373  -3.758779  -2.081866  -2.774706
# 2   0.242439 -0.199327 -0.048325   2.851120  -6.355582  -6.539099
# 3  -1.700736  0.257773 -0.438403 -10.362838  -1.674320   0.008057
# 4   0.753143  1.828821  1.377363   0.206028   1.005948   3.539271
# 5  -1.534721 -1.001002  1.536258   5.445132  -4.250478  -4.049516
# 6   0.005127 -2.091691 -0.010724   4.533440   5.825567   6.202046
# 7  -0.120228  0.146560 -0.017621  -1.864467  -0.100819  -0.294156
# 8  -0.806982 -0.466351  0.376337  -2.357157  -1.839172  -2.375545
# 9   2.871819  0.356223  1.023008   9.482013   3.478129   4.368495
# 10 -0.597823 -0.397880  0.237862  -5.093594   2.587192   2.181421
# 11  0.472457 -1.259224 -0.594929   2.448944   1.591972   0.554533
# 12  1.095956 -0.688879 -0.754981   0.617869   2.106681   2.745729
# 13 -1.215169  0.802630 -0.975331  -2.968854  -3.920451  -4.076967
# 14  1.342356  0.272391  0.365646   3.449949   0.933752   1.265144
# 15 -0.122150 -0.969176  0.118385  -1.744714  -3.007920  -2.686853
# 16  1.012515  0.871968  0.882881   4.466959  -0.199844   0.781145
# 17 -0.913869 -1.446359  1.321783   2.373576  -2.100508  -1.463692
# 18 -1.029530 -0.536481  0.552324  -3.905601   0.713382   1.646645
# 19  1.209796  0.197921  0.239444  -0.170484  -0.572785  -0.655469
# 20  0.501872 -1.365640 -0.685377  -1.864086   4.575773   4.498276
# 21  0.138846 -1.194444 -0.165844   1.707592   0.664680   1.075111
# 22  0.640761  0.015935  0.010210   4.087404  -0.280458  -0.005180
# 23  0.527333 -0.080043 -0.042210   1.443640   1.191460   1.716667
# 24 -1.154360 -0.250803  0.289517  -4.451063  -1.476663  -1.077954
# 25 -2.213333 -0.565143  1.250850  -1.379034  -3.108345  -0.914895
# 26 -1.681757 -1.102672  1.854426   4.575754  -0.320938  -0.480221
# 27 -1.788094 -0.782282  1.398795   4.435091  -1.767964  -1.253255
# 28 -2.218535  3.041686 -6.748087 -26.670050 -10.869542 -10.701244
# 29 -0.647431 -0.626081  0.405344   1.695402  -1.902068  -0.531539
# ..       ...       ...       ...        ...        ...        ...
# 50  0.232490 -1.589809 -0.369615   6.340269   0.242142   0.521983
# 51  0.867612 -0.979526 -0.849848   5.655119   3.572659   3.163057
# 52 -1.148213  0.122762 -0.140956   0.098169   0.519593  -0.050124
# 53  2.114344  1.689292  3.571745  11.317096   1.540009   1.560911
# 54  1.000943  0.177750  0.177917  -3.783250   3.841883   3.265740
# 55 -0.051415  0.032006 -0.001646  -4.340755   0.318656  -0.785064
# 56  0.159788  1.933216  0.308904  -2.770391  -2.667539  -4.077526
# 57 -0.716264 -1.062095  0.760740   3.532902   0.996094   0.056129
# 58  0.050523 -0.732629 -0.037014   0.660609   4.677403   3.955151
# 59 -0.143337  0.842741 -0.120796  -2.924017  -7.141907  -6.890383
# 60  0.943575  1.076740  1.015985   4.100955   3.048530   3.127046
# 61  0.357644  0.457691  0.163690  -3.808452   5.172276   4.335031
# 62 -0.083449 -2.619493  0.218595   4.639422   2.519303   3.614098
# 63  0.677806  0.739046  0.500930  -0.501128   3.025155   1.810959
# 64  0.556060  0.667501  0.371171   5.682124   3.386962   4.346927
# 65  0.222719  0.046403  0.010335   1.376431   2.193052   1.025252
# 66 -1.528985  0.666078 -1.018423  -8.065500  -2.601121  -2.935211
# 67  1.029211  1.407948  1.449076   3.162104   4.411606   5.239030
# 68 -1.166259  0.051149 -0.059653  -6.866684   0.907692   1.772709
# 69 -1.009562 -0.935975  0.944924   2.274129  -0.117759  -0.973164
# 70 -0.105268 -1.839109  0.193599  -0.419757   3.786033   3.857850
# 71  0.512022  0.063779  0.032656   1.195708  -0.802006  -1.927961
# 72  1.407728 -0.713968 -1.005073   4.936858   3.632077   3.425768
# 73 -1.687696 -0.561885  0.948291   1.071226  -1.983845  -1.562264
# 74  1.471234 -1.132469 -1.666127   1.836164   4.465307   3.913018
# 75  1.636463  0.274291  0.448867  12.537941   1.832746   3.313798
# 76 -0.461395  0.735912 -0.339546   0.065755   2.004543   2.500469
# 77 -0.201362  0.434319 -0.087455   2.778025   0.539524   1.222197
# 78 -0.571817 -1.120041  0.640458   1.304500   2.320586   1.755210
# 79 -0.603299  0.889095 -0.536390  -6.524522  -4.846071  -4.977877
#
# [80 rows x 6 columns]
# name = sns
#
# KeyboardInterrupt

# %%
from PIL import Image
import time
from IPython.display import clear_output
from ipythonblocks import BlockGrid, colors

imdata = Image.open('/Users/Jackie/Desktop/乖乖.jpg').getdata()

rows, cols = imdata.size
grid = BlockGrid(width=rows, height=cols,
                block_size=4, lines_on=False)
for block, rgb in zip(grid, imdata):
    block.rgb = rgb
grid.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-44c78d2da0c6> in <module>()
#       2 import time
#       3 from IPython.display import clear_output
# ----> 4 from ipythonblocks import BlockGrid, colors
#       5
#       6 imdata = Image.open('/Users/Jackie/Desktop/乖乖.jpg').getdata()
#
# ImportError: No module named ipythonblocks
